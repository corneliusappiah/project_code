# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
import scipy 
import ast
import statistics
from ydata_profiling import ProfileReport
from adjustText import adjust_text

# %%
df=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Outpatient/Op_WL 2018.csv')

# %%
df
# Out:
#       Archive_Date  Specialty_HIPE   Speciality Adult_Child Age_Profile  \
# 0       31-01-2018           100.0   Cardiology       Child        0-15
# 1       31-01-2018           100.0   Cardiology       Child        0-15
# 2       31-01-2018           100.0   Cardiology       Child        0-15
# 3       31-01-2018           100.0   Cardiology       Child        0-15
# 4       31-01-2018           100.0   Cardiology       Child        0-15
# ...            ...             ...          ...         ...         ...
# 82948   31-12-2018          8003.0  Pain Relief       Adult         65+
# 82949   31-12-2018          8003.0  Pain Relief       Adult         65+
# 82950   31-12-2018          8003.0  Pain Relief       Adult         65+
# 82951   31-12-2018          8003.0  Pain Relief       Adult         65+
# 82952   31-12-2018          8003.0  Pain Relief       Adult         65+
#
#          Time_Bands  Total
# 0        0-3 Months    167
# 1        3-6 Months    157
# ...

# %%
df1=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Outpatient/Op_WL 2019.csv') 
df1
# Out:
#       Archive_Date  Specialty_HIPE            Speciality Adult_Child  \
# 0       31-01-2019             300           Dermatology       Child
# 1       31-01-2019             402     Diabetes Mellitus       Child
# 2       31-01-2019             600  Otolaryngology (ENT)       Child
# 3       31-01-2019             600  Otolaryngology (ENT)       Child
# 4       31-01-2019             600  Otolaryngology (ENT)       Child
# ...            ...             ...                   ...         ...
# 80231   31-12-2019            7800               Urology       Adult
# 80232   31-12-2019            8003           Pain Relief       Adult
# 80233   31-12-2019            8003           Pain Relief       Adult
# 80234   31-12-2019            8003           Pain Relief       Adult
# 80235   31-12-2019            8003           Pain Relief       Adult
#
#       Age_Profile    Time_Bands  Total
# 0           16-64   9-12 Months      4
# 1            0-15    0-3 Months      6
# ...

# %%
df2=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Outpatient/Op_WL 2020.csv')
df2
# Out:
#       Archive_Date  Specialty_HIPE            Speciality Adult_Child  \
# 0       31-01-2020             601        Paediatric ENT       Child
# 1       31-01-2020             601        Paediatric ENT       Child
# 2       31-01-2020             601        Paediatric ENT       Child
# 3       31-01-2020             601        Paediatric ENT       Child
# 4       31-01-2020            1302  Paediatric Neurology       Child
# ...            ...             ...                   ...         ...
# 85268   31-12-2020            8003           Pain Relief       Adult
# 85269   31-12-2020            8003           Pain Relief       Adult
# 85270   31-12-2020            8003           Pain Relief       Adult
# 85271   31-12-2020            8003           Pain Relief       Adult
# 85272   31-12-2020            8003           Pain Relief       Adult
#
#       Age_Profile    Time_Bands  Total
# 0            0-15   18 Months +   1420
# 1           16-64    0-3 Months     18
# ...

# %%
df3=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Outpatient/Op_WL 2021.csv')
df3
# Out:
#       Archive_Date  Specialty_HIPE            Speciality Adult_Child  \
# 0       31-01-2021             601        Paediatric ENT       Child
# 1       31-01-2021            1302  Paediatric Neurology       Child
# 2       31-01-2021            1302  Paediatric Neurology       Child
# 3       31-01-2021            1503           Gynaecology       Child
# 4       31-01-2021            1503           Gynaecology       Child
# ...            ...             ...                   ...         ...
# 22516   31-03-2021            7800               Urology       Adult
# 22517   31-03-2021            7800               Urology       Adult
# 22518   31-03-2021            7800               Urology       Adult
# 22519   31-03-2021            8003           Pain Relief       Adult
# 22520   31-03-2021            8003           Pain Relief       Adult
#
#       Age_Profile    Time_Bands  Total
# 0            0-15    6-9 Months    292
# 1            0-15  15-18 Months     22
# ...

# %%
df_con=pd.concat([df,df1,df2,df3],ignore_index=True)

# %%
df_con
# Out:
#        Archive_Date  Specialty_HIPE   Speciality Adult_Child Age_Profile  \
# 0        31-01-2018           100.0   Cardiology       Child        0-15
# 1        31-01-2018           100.0   Cardiology       Child        0-15
# 2        31-01-2018           100.0   Cardiology       Child        0-15
# 3        31-01-2018           100.0   Cardiology       Child        0-15
# 4        31-01-2018           100.0   Cardiology       Child        0-15
# ...             ...             ...          ...         ...         ...
# 270978   31-03-2021          7800.0      Urology       Adult       16-64
# 270979   31-03-2021          7800.0      Urology       Adult         65+
# 270980   31-03-2021          7800.0      Urology       Adult         65+
# 270981   31-03-2021          8003.0  Pain Relief       Adult         65+
# 270982   31-03-2021          8003.0  Pain Relief       Adult         65+
#
#           Time_Bands  Total
# 0         0-3 Months    167
# 1         3-6 Months    157
# ...

# %%
df_H=df_con.copy()

# %%
df_H.groupby(by='Archive_Date').size()
# Out:
# Archive_Date
# 28-02-2018    6927
# 28-02-2019    6719
# 28-02-2021    7526
# 29-02-2020    6680
# 30-04-2018    6954
# 30-04-2019    6669
# 30-04-2020    6907
# 30-06-2018    6951
# 30-06-2019    6635
# 30-06-2020    7150
# 30-09-2018    6913
# 30-09-2019    6739
# 30-09-2020    7377
# 30-11-2018    6871
# 30-11-2019    6693
# 30-11-2020    7370
# 31-01-2018    6926
# 31-01-2019    6678
# 31-01-2020    6693
# 31-01-2021    7458
# 31-03-2018    6965
# 31-03-2019    6774
# 31-03-2020    6756
# 31-03-2021    7537
# 31-05-2018    6954
# 31-05-2019    6645
# 31-05-2020    7051
# 31-07-2018    6882
# 31-07-2019    6645
# 31-07-2020    7244
# 31-08-2018    6936
# 31-08-2019    6687
# 31-08-2020    7354
# 31-10-2018    6894
# 31-10-2019    6705
# 31-10-2020    7379
# 31-12-2018    6780
# 31-12-2019    6647
# 31-12-2020    7312
# dtype: int64

# %%
df_H
# Out:
#        Archive_Date  Specialty_HIPE   Speciality Adult_Child Age_Profile  \
# 0        31-01-2018           100.0   Cardiology       Child        0-15
# 1        31-01-2018           100.0   Cardiology       Child        0-15
# 2        31-01-2018           100.0   Cardiology       Child        0-15
# 3        31-01-2018           100.0   Cardiology       Child        0-15
# 4        31-01-2018           100.0   Cardiology       Child        0-15
# ...             ...             ...          ...         ...         ...
# 270978   31-03-2021          7800.0      Urology       Adult       16-64
# 270979   31-03-2021          7800.0      Urology       Adult         65+
# 270980   31-03-2021          7800.0      Urology       Adult         65+
# 270981   31-03-2021          8003.0  Pain Relief       Adult         65+
# 270982   31-03-2021          8003.0  Pain Relief       Adult         65+
#
#           Time_Bands  Total
# 0         0-3 Months    167
# 1         3-6 Months    157
# ...

# %%
df_H.rename(columns={'Speciality':"Specialty_Name"},inplace=True)

# %%
df_H
# Out:
#        Archive_Date  Specialty_HIPE Specialty_Name Adult_Child Age_Profile  \
# 0        31-01-2018           100.0     Cardiology       Child        0-15
# 1        31-01-2018           100.0     Cardiology       Child        0-15
# 2        31-01-2018           100.0     Cardiology       Child        0-15
# 3        31-01-2018           100.0     Cardiology       Child        0-15
# 4        31-01-2018           100.0     Cardiology       Child        0-15
# ...             ...             ...            ...         ...         ...
# 270978   31-03-2021          7800.0        Urology       Adult       16-64
# 270979   31-03-2021          7800.0        Urology       Adult         65+
# 270980   31-03-2021          7800.0        Urology       Adult         65+
# 270981   31-03-2021          8003.0    Pain Relief       Adult         65+
# 270982   31-03-2021          8003.0    Pain Relief       Adult         65+
#
#           Time_Bands  Total
# 0         0-3 Months    167
# ...

# %%
df_H
# Out:
#        Archive_Date  Specialty_HIPE Specialty_Name Adult_Child Age_Profile  \
# 0        31-01-2018           100.0     Cardiology       Child        0-15
# 1        31-01-2018           100.0     Cardiology       Child        0-15
# 2        31-01-2018           100.0     Cardiology       Child        0-15
# 3        31-01-2018           100.0     Cardiology       Child        0-15
# 4        31-01-2018           100.0     Cardiology       Child        0-15
# ...             ...             ...            ...         ...         ...
# 270978   31-03-2021          7800.0        Urology       Adult       16-64
# 270979   31-03-2021          7800.0        Urology       Adult         65+
# 270980   31-03-2021          7800.0        Urology       Adult         65+
# 270981   31-03-2021          8003.0    Pain Relief       Adult         65+
# 270982   31-03-2021          8003.0    Pain Relief       Adult         65+
#
#           Time_Bands  Total
# 0         0-3 Months    167
# ...

# %%
df_H.insert(3,'Case_Type','Outpatient')

# %%
df_H
# Out:
#        Archive_Date  Specialty_HIPE Specialty_Name   Case_Type Adult_Child  \
# 0        31-01-2018           100.0     Cardiology  Outpatient       Child
# 1        31-01-2018           100.0     Cardiology  Outpatient       Child
# 2        31-01-2018           100.0     Cardiology  Outpatient       Child
# 3        31-01-2018           100.0     Cardiology  Outpatient       Child
# 4        31-01-2018           100.0     Cardiology  Outpatient       Child
# ...             ...             ...            ...         ...         ...
# 270978   31-03-2021          7800.0        Urology  Outpatient       Adult
# 270979   31-03-2021          7800.0        Urology  Outpatient       Adult
# 270980   31-03-2021          7800.0        Urology  Outpatient       Adult
# 270981   31-03-2021          8003.0    Pain Relief  Outpatient       Adult
# 270982   31-03-2021          8003.0    Pain Relief  Outpatient       Adult
#
#        Age_Profile    Time_Bands  Total
# ...

# %%
dfi1=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Inpatient/IN_WL 2018.csv')
dfi1
# Out:
#       Archive_Date  Specialty_HIPE             Specialty_Name  Case_Type  \
# 0       31-01-2018               0  Small Volume Specialities  Inpatient
# 1       31-01-2018               0  Small Volume Specialities  Inpatient
# 2       31-01-2018             400              Endocrinology   Day Case
# 3       31-01-2018             400              Endocrinology   Day Case
# 4       31-01-2018             600       Otolaryngology (ENT)   Day Case
# ...            ...             ...                        ...        ...
# 55372   31-12-2018            8003                Pain Relief   Day Case
# 55373   31-12-2018            8003                Pain Relief   Day Case
# 55374   31-12-2018            8003                Pain Relief   Day Case
# 55375   31-12-2018            8003                Pain Relief   Day Case
# 55376   31-12-2018            8003                Pain Relief   Day Case
#
#       Adult_Child Age_Profile     Time_Bands  Total  Unnamed: 8
# ...

# %%
dfi2=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Inpatient/IN_WL 2019.csv')
df2
# Out:
#       Archive_Date  Specialty_HIPE            Speciality Adult_Child  \
# 0       31-01-2020             601        Paediatric ENT       Child
# 1       31-01-2020             601        Paediatric ENT       Child
# 2       31-01-2020             601        Paediatric ENT       Child
# 3       31-01-2020             601        Paediatric ENT       Child
# 4       31-01-2020            1302  Paediatric Neurology       Child
# ...            ...             ...                   ...         ...
# 85268   31-12-2020            8003           Pain Relief       Adult
# 85269   31-12-2020            8003           Pain Relief       Adult
# 85270   31-12-2020            8003           Pain Relief       Adult
# 85271   31-12-2020            8003           Pain Relief       Adult
# 85272   31-12-2020            8003           Pain Relief       Adult
#
#       Age_Profile    Time_Bands  Total
# 0            0-15   18 Months +   1420
# 1           16-64    0-3 Months     18
# ...

# %%
dfi3=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Inpatient/IN_WL 2020.csv')
dfi3
# Out:
#       Archive_Date  Specialty_HIPE             Specialty_Name Case_Type  \
# 0       31-01-2020               0  Small Volume Specialities  Day Case
# 1       31-01-2020               0  Small Volume Specialities  Day Case
# 2       31-01-2020               0  Small Volume Specialities  Day Case
# 3       31-01-2020               0  Small Volume Specialities  Day Case
# 4       31-01-2020               0  Small Volume Specialities  Day Case
# ...            ...             ...                        ...       ...
# 58452   31-12-2020            8003                Pain Relief  Day Case
# 58453   31-12-2020            8003                Pain Relief  Day Case
# 58454   31-12-2020            8003                Pain Relief  Day Case
# 58455   31-12-2020            8003                Pain Relief  Day Case
# 58456   31-12-2020            8003                Pain Relief  Day Case
#
#       Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
dfi4=pd.read_csv('C:/Users/Cornelius/Desktop/project_code/Inpatient/IN_WL 2021.csv')
dfi4
# Out:
#       Archive_Date  Specialty_HIPE             Specialty_Name  Case_Type  \
# 0       31-01-2021               0  Small Volume Specialities   Day Case
# 1       31-01-2021               0  Small Volume Specialities   Day Case
# 2       31-01-2021               0  Small Volume Specialities   Day Case
# 3       31-01-2021               0  Small Volume Specialities   Day Case
# 4       31-01-2021               0  Small Volume Specialities  Inpatient
# ...            ...             ...                        ...        ...
# 15882   31-03-2021            8003                Pain Relief   Day Case
# 15883   31-03-2021            8003                Pain Relief   Day Case
# 15884   31-03-2021            8003                Pain Relief   Day Case
# 15885   31-03-2021            8003                Pain Relief   Day Case
# 15886   31-03-2021            8003                Pain Relief  Inpatient
#
#       Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
df_concat=pd.concat([dfi1,dfi2,dfi3,dfi4],ignore_index=True)
df_concat
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name  Case_Type  \
# 0        31-01-2018               0  Small Volume Specialities  Inpatient
# 1        31-01-2018               0  Small Volume Specialities  Inpatient
# 2        31-01-2018             400              Endocrinology   Day Case
# 3        31-01-2018             400              Endocrinology   Day Case
# 4        31-01-2018             600       Otolaryngology (ENT)   Day Case
# ...             ...             ...                        ...        ...
# 182131   31-03-2021            8003                Pain Relief   Day Case
# 182132   31-03-2021            8003                Pain Relief   Day Case
# 182133   31-03-2021            8003                Pain Relief   Day Case
# 182134   31-03-2021            8003                Pain Relief   Day Case
# 182135   31-03-2021            8003                Pain Relief  Inpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total  Unnamed: 8
# ...

# %%
df_concat.drop('Unnamed: 8',axis=1,inplace=True)

# %%
df_con
# Out:
#        Archive_Date  Specialty_HIPE   Speciality Adult_Child Age_Profile  \
# 0        31-01-2018           100.0   Cardiology       Child        0-15
# 1        31-01-2018           100.0   Cardiology       Child        0-15
# 2        31-01-2018           100.0   Cardiology       Child        0-15
# 3        31-01-2018           100.0   Cardiology       Child        0-15
# 4        31-01-2018           100.0   Cardiology       Child        0-15
# ...             ...             ...          ...         ...         ...
# 270978   31-03-2021          7800.0      Urology       Adult       16-64
# 270979   31-03-2021          7800.0      Urology       Adult         65+
# 270980   31-03-2021          7800.0      Urology       Adult         65+
# 270981   31-03-2021          8003.0  Pain Relief       Adult         65+
# 270982   31-03-2021          8003.0  Pain Relief       Adult         65+
#
#           Time_Bands  Total
# 0         0-3 Months    167
# 1         3-6 Months    157
# ...

# %%
df_c=pd.concat([df_concat,df_H],ignore_index=True)

# %%
df=df_c.copy()

# %%
df
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 1        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 2        31-01-2018           400.0              Endocrinology    Day Case
# 3        31-01-2018           400.0              Endocrinology    Day Case
# 4        31-01-2018           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   31-03-2021          7800.0                    Urology  Outpatient
# 453115   31-03-2021          7800.0                    Urology  Outpatient
# 453116   31-03-2021          7800.0                    Urology  Outpatient
# 453117   31-03-2021          8003.0                Pain Relief  Outpatient
# 453118   31-03-2021          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
df.dropna(subset="Specialty_HIPE", axis=0,inplace=True)

# %%
df
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 1        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 2        31-01-2018           400.0              Endocrinology    Day Case
# 3        31-01-2018           400.0              Endocrinology    Day Case
# 4        31-01-2018           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   31-03-2021          7800.0                    Urology  Outpatient
# 453115   31-03-2021          7800.0                    Urology  Outpatient
# 453116   31-03-2021          7800.0                    Urology  Outpatient
# 453117   31-03-2021          8003.0                Pain Relief  Outpatient
# 453118   31-03-2021          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
# Out:
# Specialty_HIPE  Specialty_Name
# 2600.0          General Surgery          43548
# 1800.0          Orthopaedics             35909
# 7800.0          Urology                  33452
# 1503.0          Gynaecology              32661
# 600.0           Otolaryngology (ENT)     32082
#                                          ...
# 8002.0          Intensive Care               6
# 1703.0          Vitro-Retinal Surgery        5
# 7100.0          Occupational Medicine        4
# 2104.0          Substance Abuse              4
# 2702.0          Tropical                     4
# Name: count, Length: 78, dtype: int64

# %%
df
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 1        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 2        31-01-2018           400.0              Endocrinology    Day Case
# 3        31-01-2018           400.0              Endocrinology    Day Case
# 4        31-01-2018           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   31-03-2021          7800.0                    Urology  Outpatient
# 453115   31-03-2021          7800.0                    Urology  Outpatient
# 453116   31-03-2021          7800.0                    Urology  Outpatient
# 453117   31-03-2021          8003.0                Pain Relief  Outpatient
# 453118   31-03-2021          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
df
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 1        31-01-2018             0.0  Small Volume Specialities   Inpatient
# 2        31-01-2018           400.0              Endocrinology    Day Case
# 3        31-01-2018           400.0              Endocrinology    Day Case
# 4        31-01-2018           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   31-03-2021          7800.0                    Urology  Outpatient
# 453115   31-03-2021          7800.0                    Urology  Outpatient
# 453116   31-03-2021          7800.0                    Urology  Outpatient
# 453117   31-03-2021          8003.0                Pain Relief  Outpatient
# 453118   31-03-2021          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453119 entries, 0 to 453118
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Archive_Date    453119 non-null  object
#  1   Specialty_HIPE  452928 non-null  float64
#  2   Specialty_Name  453119 non-null  object
#  3   Case_Type       453119 non-null  object
#  4   Adult_Child     453119 non-null  object
#  5   Age_Profile     452944 non-null  object
#  6   Time_Bands      453117 non-null  object
#  7   Total           453119 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 27.7+ MB

# %%
df['Archive_Date']=pd.to_datetime(df['Archive_Date'])
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_10688\2514471287.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Archive_Date']=pd.to_datetime(df['Archive_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453119 entries, 0 to 453118
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Archive_Date    453119 non-null  datetime64[ns]
#  1   Specialty_HIPE  452928 non-null  float64
#  2   Specialty_Name  453119 non-null  object
#  3   Case_Type       453119 non-null  object
#  4   Adult_Child     453119 non-null  object
#  5   Age_Profile     452944 non-null  object
#  6   Time_Bands      453117 non-null  object
#  7   Total           453119 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.7+ MB

# %%
df['Month_name']=df['Archive_Date'].dt.strftime('%b')

# %%
df
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 1        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 2        2018-01-31           400.0              Endocrinology    Day Case
# 3        2018-01-31           400.0              Endocrinology    Day Case
# 4        2018-01-31           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   2021-03-31          7800.0                    Urology  Outpatient
# 453115   2021-03-31          7800.0                    Urology  Outpatient
# 453116   2021-03-31          7800.0                    Urology  Outpatient
# 453117   2021-03-31          8003.0                Pain Relief  Outpatient
# 453118   2021-03-31          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total Month_name
# ...

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(df):
    # Drop rows with missing data in column: 'Specialty_HIPE'
    df = df.dropna(subset=['Specialty_HIPE'])
    # Drop rows with missing data in column: 'Age_Profile'
    df = df.dropna(subset=['Age_Profile'])
    # Drop rows with missing data in column: 'Time_Bands'
    df = df.dropna(subset=['Time_Bands'])
    return df

df_clean = clean_data(df.copy())
df_clean
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 1        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 2        2018-01-31           400.0              Endocrinology    Day Case
# 3        2018-01-31           400.0              Endocrinology    Day Case
# 4        2018-01-31           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   2021-03-31          7800.0                    Urology  Outpatient
# 453115   2021-03-31          7800.0                    Urology  Outpatient
# 453116   2021-03-31          7800.0                    Urology  Outpatient
# 453117   2021-03-31          8003.0                Pain Relief  Outpatient
# 453118   2021-03-31          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total Month_name
# ...

# %%
profie=ProfileReport(df_clean,title='profiling report')

# %%
profie.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-29 08:23:31.189953&quot;&gt;&lt;title&gt;profiling report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_clean
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 1        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 2        2018-01-31           400.0              Endocrinology    Day Case
# 3        2018-01-31           400.0              Endocrinology    Day Case
# 4        2018-01-31           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   2021-03-31          7800.0                    Urology  Outpatient
# 453115   2021-03-31          7800.0                    Urology  Outpatient
# 453116   2021-03-31          7800.0                    Urology  Outpatient
# 453117   2021-03-31          8003.0                Pain Relief  Outpatient
# 453118   2021-03-31          8003.0                Pain Relief  Outpatient
#
#        Adult_Child Age_Profile     Time_Bands  Total Month_name
# ...

# %%
df_clean['Month_no']=df_clean['Archive_Date'].dt.month
df_clean
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 1        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 2        2018-01-31           400.0              Endocrinology    Day Case
# 3        2018-01-31           400.0              Endocrinology    Day Case
# 4        2018-01-31           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   2021-03-31          7800.0                    Urology  Outpatient
# 453115   2021-03-31          7800.0                    Urology  Outpatient
# 453116   2021-03-31          7800.0                    Urology  Outpatient
# 453117   2021-03-31          8003.0                Pain Relief  Outpatient
# 453118   2021-03-31          8003.0                Pain Relief  Outpatient
#
# ...

# %%
df_clean['Case_Type'].value_counts().plot(kind="pie", startangle=90,autopct="%1.2f%%")
plt.title('Percentage count of the Various Case Type in the Hospital')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df_pivot=df_clean.pivot_table(columns='Case_Type',index='Month_no',values='Total')
df_pivot.reset_index(inplace=True)

# %%
df_pivot
# Out:
# Case_Type  Month_no   Day Case  Inpatient  Outpatient
# 0                 1  19.011920  11.956426   79.488169
# 1                 2  18.600828  11.711396   80.023547
# 2                 3  19.023460  11.778468   80.044578
# 3                 4  19.992875  12.131183   79.346159
# 4                 5  19.531665  12.108324   79.714168
# 5                 6  19.345964  11.924364   79.948998
# 6                 7  18.627259  11.676177   80.864658
# 7                 8  18.169129  11.399893   80.914748
# 8                 9  17.914306  11.474644   80.748595
# 9                10  17.789591  11.577936   80.907140
# 10               11  17.756663  11.456936   80.839451
# 11               12  18.373635  11.710788   80.855013

# %%
df_pivot['Month']=df_pivot['Month_no'].apply(lambda x: pd.to_datetime(x,format='%m').strftime("%b"))

df_pivot
# Out:
# Case_Type  Month_no   Day Case  Inpatient  Outpatient Month
# 0                 1  19.011920  11.956426   79.488169   Jan
# 1                 2  18.600828  11.711396   80.023547   Feb
# 2                 3  19.023460  11.778468   80.044578   Mar
# 3                 4  19.992875  12.131183   79.346159   Apr
# 4                 5  19.531665  12.108324   79.714168   May
# 5                 6  19.345964  11.924364   79.948998   Jun
# 6                 7  18.627259  11.676177   80.864658   Jul
# 7                 8  18.169129  11.399893   80.914748   Aug
# 8                 9  17.914306  11.474644   80.748595   Sep
# 9                10  17.789591  11.577936   80.907140   Oct
# 10               11  17.756663  11.456936   80.839451   Nov
# 11               12  18.373635  11.710788   80.855013   Dec

# %%
df_pivot.set_index('Month',inplace=True)

# %%
df_pivot
# Out:
# Case_Type  Month_no   Day Case  Inpatient  Outpatient
# Month
# Jan               1  19.011920  11.956426   79.488169
# Feb               2  18.600828  11.711396   80.023547
# Mar               3  19.023460  11.778468   80.044578
# Apr               4  19.992875  12.131183   79.346159
# May               5  19.531665  12.108324   79.714168
# Jun               6  19.345964  11.924364   79.948998
# Jul               7  18.627259  11.676177   80.864658
# Aug               8  18.169129  11.399893   80.914748
# Sep               9  17.914306  11.474644   80.748595
# Oct              10  17.789591  11.577936   80.907140
# Nov              11  17.756663  11.456936   80.839451
# Dec              12  18.373635  11.710788   80.855013

# %%
df_pivot.drop(columns="Month_no",inplace=True)

# %%
df_pivot
# Out:
# Case_Type   Day Case  Inpatient  Outpatient
# Month
# Jan        19.011920  11.956426   79.488169
# Feb        18.600828  11.711396   80.023547
# Mar        19.023460  11.778468   80.044578
# Apr        19.992875  12.131183   79.346159
# May        19.531665  12.108324   79.714168
# Jun        19.345964  11.924364   79.948998
# Jul        18.627259  11.676177   80.864658
# Aug        18.169129  11.399893   80.914748
# Sep        17.914306  11.474644   80.748595
# Oct        17.789591  11.577936   80.907140
# Nov        17.756663  11.456936   80.839451
# Dec        18.373635  11.710788   80.855013

# %%
df_pivot.plot(kind='bar')
plt.title('Total case of Case_Types for Each Month')
# Out:
# <Axes: xlabel='Month'>

# %%
df_clean
# Out:
#        Archive_Date  Specialty_HIPE             Specialty_Name   Case_Type  \
# 0        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 1        2018-01-31             0.0  Small Volume Specialities   Inpatient
# 2        2018-01-31           400.0              Endocrinology    Day Case
# 3        2018-01-31           400.0              Endocrinology    Day Case
# 4        2018-01-31           600.0       Otolaryngology (ENT)    Day Case
# ...             ...             ...                        ...         ...
# 453114   2021-03-31          7800.0                    Urology  Outpatient
# 453115   2021-03-31          7800.0                    Urology  Outpatient
# 453116   2021-03-31          7800.0                    Urology  Outpatient
# 453117   2021-03-31          8003.0                Pain Relief  Outpatient
# 453118   2021-03-31          8003.0                Pain Relief  Outpatient
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Cornelius\anaconda3\envs\cornelius_project\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Archive_Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ...
