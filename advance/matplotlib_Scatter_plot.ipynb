# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
import scipy 
import ast

# %%
data={
    'Job_skils':['python','sql','java','c++','c#','javascript','html','css','php','ruby'],
    'skill_count':[30,25,20,15,10,5,3,4,2,1],
    'skill_pay':[100,90,80,70,60,50,40,30,20,10]
}
df1=pd.DataFrame(data)
df1
# Out:
#     Job_skils  skill_count  skill_pay
# 0      python           30        100
# 1         sql           25         90
# 2        java           20         80
# 3         c++           15         70
# 4          c#           10         60
# 5  javascript            5         50
# 6        html            3         40
# 7         css            4         30
# 8         php            2         20
# 9        ruby            1         10

# %%
df1.plot(kind='scatter',x='skill_count',y='skill_pay')
# Out:
# <Axes: xlabel='skill_count', ylabel='skill_pay'>

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df["job_posted_date"]=pd.to_datetime(df['job_posted_date'])
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Cornelius\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Sat Aug  3 02:06:02 2024).

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df=df[df['job_title_short']=='Data Analyst']
df
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_explode=df.explode('job_skills')
df_explode
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
skill_stats=df_explode.groupby('job_skills').agg(
    skill_count=('job_skills','count'),
    median_salary=('salary_year_avg','median')
    )
skill_stats=skill_stats.sort_values(by="skill_count", ascending=False).head(20)
skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428   92500.000000
# excel             66860   84479.000000
# python            57190   98500.000000
# tableau           46455   95000.000000
# power bi          39380   90000.000000
# r                 29996   92527.500000
# sas               27998   90000.000000
# powerpoint        13822   85000.000000
# word              13562   80000.000000
# sap               11280   90000.000000
# azure             10913  100000.000000
# oracle            10387   95000.000000
# aws                9047  100500.000000
# sql server         8288   92150.000000
# go                 7905   90000.000000
# flow               7259   94450.000000
# vba                6841   90000.000000
# looker             6259  104000.000000
# snowflake          6178  110240.109375
# qlik               5681  100000.000000

# %%
# %pip install adjustText
# Out:
# ...
#
# ...

# %%
from adjustText import adjust_text

# %%
skill_stats.plot(kind="scatter",x='skill_count',y='median_salary')
plt.xlabel('Count of Job Posting')
plt.ylabel('Median Year Salary (USD$)')
plt.title('Salary Vs Count of Job Posting for Top Ten Skills')
plt.tight_layout()
text=[]
for i,txt in enumerate(skill_stats.index):
    text.append(plt.text(skill_stats['skill_count'].iloc[i],skill_stats['median_salary'].iloc[i], txt))
    adjust_text(text)
plt.show()

# %%
skill_stats.plot(kind="scatter",x='skill_count',y='median_salary')
plt.xlabel('Count of Job Posting')
plt.ylabel('Median Year Salary (USD$)')
plt.title('Salary Vs Count of Job Posting for Top Ten Skills')
plt.tight_layout()
text=[]
for i,txt in enumerate(skill_stats.index):
    text.append(plt.text(skill_stats['skill_count'].iloc[i],skill_stats['median_salary'].iloc[i], txt))
adjust_text(text,arrowprops=dict(arrowstyle="-",color='r',lw=0.5))
ax=plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormtter(lambda x,pos: x))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 11
#       9 adjust_text(text,arrowprops=dict(arrowstyle="-",color='r',lw=0.5))
#      10 ax=plt.gca()
# ---> 11 ax.yaxis.set_major_formatter(plt.FuncFormtter(lambda x,pos: x))
#      12 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'FuncFormtter'
