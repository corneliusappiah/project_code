# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from datasets import load_dataset
import ast

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df["job_posted_date"]=pd.to_datetime(df['job_posted_date'])
#using lambda
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
df
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Cornelius\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Sat Aug  3 02:06:02 2024).
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# ...

# %%
df_skill=df.copy()
df_skill=df_skill.explode('job_skills')
skill_count=df_skill.groupby(['job_skills','job_title_short']).size()
df_skill_count= skill_count.reset_index(name='skill_count')
df_skill_count.sort_values(by="skill_count",ascending=False,inplace=True)
df_skill_count
# Out:
#       job_skills            job_title_short  skill_count
# 1480      python             Data Scientist       113711
# 1822         sql              Data Engineer       113130
# 1479      python              Data Engineer       108022
# 1821         sql               Data Analyst        92428
# 1823         sql             Data Scientist        78982
# ...          ...                        ...          ...
# 2173       webex      Senior Data Scientist            1
# 1054  mattermost             Data Scientist            1
# 270      clickup  Machine Learning Engineer            1
# 797       heroku        Senior Data Analyst            1
# 1128    msaccess               Data Analyst            1
#
# [2256 rows x 3 columns]

# %%
job_titles=['Data Analyst','Data Engineer','Data Scientist']

# %%
fig,ax=plt.subplots(3,1)
for i,job_title in enumerate(job_titles):
 print(i,job_title)
# Out:
# 0 Data Analyst
# 1 Data Engineer
# 2 Data Scientist

# %%
fig,ax=plt.subplots(3,1)
for i,job_title in enumerate(job_titles):
 df_plot=df_skill_count[df_skill_count['job_title_short']==job_title].head(5)
 df_plot.plot(kind='barh',x="job_skills",ylabel="skill_values",ax=ax[i],title=job_title)
 ax[i].invert_yaxis()
 ax[i].set_ylabel('')
 ax[i].legend().set_visible(False)
 ax[i].set_xlim(0,120000)
 fig.suptitle('count of top top skills in job postin',fontsize=15)
 fig.tight_layout()
