# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
import scipy 
import ast

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df["job_posted_date"]=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\Cornelius\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Sat Aug  3 02:06:02 2024).

# %%
import seaborn as sns

# %%
df_DA_Us=df[(df['job_title_short']=='Data Analyst')& (df['job_country']=='United States')]
df_DA_Us
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
df_DA_Us=df_DA_Us.dropna(subset=['salary_year_avg'])

# %%
df_DA_Us['salary_year_avg']
# Out:
# 109        89000.0
# 180        90250.0
# 410       133285.0
# 988        62623.0
# 1413       71300.0
#             ...
# 782637     70000.0
# 782798    111175.0
# 783588    125000.0
# 783866    115000.0
# 784882     87500.0
# Name: salary_year_avg, Length: 4350, dtype: float64

# %%
df_DA_Us=df_DA_Us.explode('job_skills')

# %%
df_top_pay=df_DA_Us.groupby('job_skills')["salary_year_avg"].agg(['count','median']).sort_values(by='median',ascending=False).head(10)
df_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_skills=df_DA_Us.groupby('job_skills')["salary_year_avg"].agg(['count','median']).sort_values(by='count',ascending=False).head(10)
df_skills=df_skills.sort_values(by='median').head(10)

# %%
df_skills
# Out:
#             count    median
# job_skills
# word          461  81194.75
# excel        1808  84392.00
# powerpoint    462  85000.00
# sas           926  90000.00
# power bi      838  90000.00
# sql          2508  91000.00
# r             893  92500.00
# sql server    286  92500.00
# tableau      1364  92875.00
# python       1431  97500.00

# %%
fig,ax=plt.subplots(2,1)
#[::-1] is to invert the axis, normally ax[0].invert_yaxis()is used
df_top_pay[::-1].plot(kind='barh',y='median',ax=ax[0],legend=False)
ax[0].set_title('Top 10 Heightest Paid Skills For Data Analyst')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
plt.tight_layout()

df_skills.plot(kind='barh',y='median',ax=ax[1],legend=False)
plt.title('Top 10 Most in demand Data Analyst Skills')
plt.xlabel('')
plt.ylabel('median Salary (USD)')
plt.tight_layout()
ax[1].set_xlim(ax[0].get_xlim())
# Out:
# (0.0, 206062.5)

# %%
fig,ax=plt.subplots(2,1)
sns.set_theme(style='ticks')
#[::-1] is to invert the axis, normally ax[0].invert_yaxis()is used
#df_top_pay[::-1].plot(kind='barh',y='median',ax=ax[0],legend=False)
sns.barplot(data=df_top_pay,x='median',y=df_top_pay.index,ax=ax[0],hue='median',palette='dark:b_r')
ax[0].set_title('Top 10 Heightest Paid Skills For Data Analyst')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].legend().remove()
plt.tight_layout()

#df_skills.plot(kind='barh',y='median',ax=ax[1],legend=False)
sns.barplot(data=df_skills,x='median',y=df_skills.index,ax=ax[1],hue='median',palette='light:b_r')
ax[1].set_title('Top 10 Most in demand Data Analyst Skills')
ax[1].set_xlabel('')
ax[1].set_ylabel('median Salary (USD)')
ax[1].legend().remove()
plt.tight_layout()
ax[1].set_xlim(ax[0].get_xlim()) # setting the same x-axis limit as the first
# Out:
# (0.0, 206062.5)

# %%
df_DA_Us['salary_year_avg'].plot(kind="hist",bins=30,edgecolor='black')
plt.xlim(0,250000)
# Out:
# (0.0, 250000.0)

# %%
sns.displot(df_DA_Us['salary_year_avg'],kind='kde',fill=True)
plt.title('Distribution of United States Data Analyst Yearly Salary')
plt.xlabel("Yearly Salary (USD)")
plt.ylabel('Number of Jobs')
# Out:
# Text(12.444444444444445, 0.5, 'Number of Jobs')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
job_titles=['Data Analyst','Data Engineer','Data Scientist']

# %%
df_us=df[(df['job_title_short'].isin(job_titles)) & (df['job_country']=='United States')].dropna(subset=['salary_year_avg'])

# %%
df_us
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_list=[df_us[df_us['job_title_short']==job_title]['salary_year_avg'] for job_title in job_titles]

# %%
job_list
# Out:
# [109        89000.0
#  180        90250.0
#  410       133285.0
#  988        62623.0
#  1413       71300.0
#              ...
#  782637     70000.0
#  782798    111175.0
#  783588    125000.0
#  783866    115000.0
#  784882     87500.0
#  Name: salary_year_avg, Length: 4350, dtype: float64,
#  92        120000.0
#  146       129500.0
#  307       185000.0
#  339       195000.0
#  380        97500.0
#              ...
#  783111    125000.0
#  784102     90000.0
#  784191    217500.0
#  785624    139216.0
#  785641    150000.0
#  Name: salary_year_avg, Length: 2915, dtype: float64,
#  100       228222.0
#  116       114000.0
#  257       103128.0
#  450       157500.0
#  1257       70700.0
#              ...
#  785324    234500.0
#  785488    115000.0
#  785563    136400.0
#  785648    221875.0
#  785692    157500.0
#  Name: salary_year_avg, Length: 4553, dtype: float64]

# %%
plt.boxplot(job_list,labels=job_titles, vert=False)
plt.title('salary Distributions in the United State')
plt.xlabel('Year Salary (USD)')
plt.xlim(0,600000)
ticks_x=plt.FuncFormatter(lambda y,pos: f'${int(y/1000)}k')
plt.gca().xaxis.set_major_formatter(ticks_x)
plt.show()
# Out:
# C:\Users\Cornelius\AppData\Local\Temp\ipykernel_6856\2692344134.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_list,labels=job_titles, vert=False)

# %%
import seaborn as sns

# %%
sns.boxplot(data=df_us,x='salary_year_avg',y='job_title_short')
plt.title('salary Distributions in the United State')
plt.xlabel('Year Salary (USD)')
plt.ylabel('')
plt.xlim(0,600000)
ticks_x=plt.FuncFormatter(lambda y,pos: f'${int(y/1000)}k')
plt.gca().xaxis.set_major_formatter(ticks_x)
plt.show()
